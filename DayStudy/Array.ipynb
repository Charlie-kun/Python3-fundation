# %%
import random
import numpy as np

#num=random.random()
#float_num=round(num,2)
#temp=random.randrange(22,24)
#hit=np.array(1,)

#hit = np.random.randint(22,24,(100,1))

#print(hit)

#hit=np.array()
hit=[]

for i in range(100):
    num=random.random()
    float_num=round(num,2)
    temp=random.randrange(22,24)
    hit.append((temp+float_num))

print(hit)

hit=np.transpose(hit)

hit.reshape(100,1)
# Out:
# [23.94, 23.24, 22.06, 23.1, 23.93, 22.48, 22.83, 23.9, 23.26, 23.28, 22.45, 22.2, 23.56, 22.35, 22.26, 23.48, 23.65, 23.91, 23.85, 22.45, 23.31, 22.25, 23.74, 22.89, 24.0, 22.4, 23.3, 22.41, 22.97, 22.35, 23.3, 22.19, 22.69, 22.2, 22.3, 23.58, 23.23, 23.18, 22.93, 22.68, 23.88, 23.71, 22.54, 22.71, 23.81, 22.08, 22.97, 22.92, 22.38, 22.66, 22.54, 23.41, 23.61, 23.38, 23.79, 23.58, 22.79, 22.91, 22.15, 22.63, 22.92, 22.96, 23.96, 23.85, 23.39, 23.12, 23.13, 23.23, 23.17, 23.82, 22.2, 23.6, 22.8, 22.28, 22.38, 23.41, 23.55, 22.43, 23.67, 22.83, 23.75, 23.03, 22.74, 22.28, 22.75, 23.91, 22.44, 23.92, 23.61, 22.44, 23.34, 23.45, 22.15, 22.12, 23.36, 22.59, 22.1, 23.49, 23.91, 22.78]
# array([[23.94],
#        [23.24],
#        [22.06],
#        [23.1 ],
#        [23.93],
#        [22.48],
#        [22.83],
#        [23.9 ],
#        [23.26],
#        [23.28],
#        [22.45],
#        [22.2 ],
#        [23.56],
#        [22.35],
#        [22.26],
#        [23.48],
#        [23.65],
# ...
